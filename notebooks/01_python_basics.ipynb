# %%
import pandas as pd
import sklearn
import geopandas as gpd
print("OK")
# Out:
# OK

# %%
age=16
print(age)
print(type(age))
# Out:
# 16
# <class 'int'>

# %%
numbers=[2,4,6]
print(numbers[1])
# Out:
# 4

# %%
student={
    "grade":11,
    "gpa":4.2
}
print(student["gpa"])
# Out:
# 4.2

# %%
ages =[14,16,18,20]

for age in ages:
    if age >=18:
        print(age,"is an adult")
    else:
        print(age,"is a minor")
# Out:
# 14 is a minor
# 16 is a minor
# 18 is an adult
# 20 is an adult

# %%
import pandas as pd

# %%
data={
    "age":[25,30,45,50],
    "education":["HS","College","College","Graduate"]
}
df=pd.DataFrame(data)
df
# Out:
#    age education
# 0   25        HS
# 1   30   College
# 2   45   College
# 3   50  Graduate

# %%
df["income"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rhyth\miniconda3\envs\inequality-ml\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'income'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ...

# %%
df.columns
# Out:
# Index(['age', 'education'], dtype='object')

# %%
import pandas as pd
data={
    "age":[25,30,45,50],
    "education":["HS","College","College","Graduate"],
    "income":[30000,50000,70000,90000]
}
df=pd.DataFrame(data)
df
# Out:
#    age education  income
# 0   25        HS   30000
# 1   30   College   50000
# 2   45   College   70000
# 3   50  Graduate   90000

# %%
df["income"].mean()
# Out:
# np.float64(60000.0)

# %%
df.groupby("education").income.mean()
# Out:
# education
# College     60000.0
# Graduate    90000.0
# HS          30000.0
# Name: income, dtype: float64

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df=pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df=pd.DataFrame(data)
#
# NameError: name 'pd' is not defined

# %%
df=pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df=pd.DataFrame(data)
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
#    age education
# 0   25        HS
# 1   30   College
# 2   45   College
# 3   50  Graduate

# %%
import matplotlib.pyplot as plt

df.groupby("education")["income"].mean().plot(kind="bar")
plt.title("Average Income by Education")
plt.ylabel("Income ($)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 df.groupby("education")["income"].mean().plot(kind="bar")
#       4 plt.title("Average Income by Education")
#       5 plt.ylabel("Income ($)")
#
# File c:\Users\rhyth\miniconda3\envs\inequality-ml\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'education'], dtype='object')

# %%
import pandas as pd
data={
    "age":[25,30,45,50],
    "education":["HS","College","College","Graduate"],
    "income":[30000,50000,70000,90000]
}
df=pd.DataFrame(data)
df
# Out:
#    age education  income
# 0   25        HS   30000
# 1   30   College   50000
# 2   45   College   70000
# 3   50  Graduate   90000

# %%
import matplotlib.pyplot as plt

df.groupby("education")["income"].mean().plot(kind="bar")
plt.title("Average Income by Education")
plt.ylabel("Income ($)")
plt.show()

# %%
# Out:
# Index(['age', 'education', 'income'], dtype='object')
